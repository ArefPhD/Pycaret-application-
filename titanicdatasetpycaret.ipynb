# %%
# !pip install pycaret
# !pip install pycaret --user
# !pip install markupsafe==2.0.1

# %%
from google.colab import files

uploaded = files.upload()
import pandas as pd
df=pd.read_csv('train.csv')
from pycaret.datasets import get_data
dataset = df
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
df
import jinja2
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'Survived', session_id=123)
best_model = compare_models()
print(best_model)
models()
dt = create_model('gbc')
#trained model object is stored in the variable 'dt'. 
print(dt)
tuned_dt = tune_model(dt)
print(tuned_dt)
plot_model(tuned_dt, plot = 'auc')
plot_model(tuned_dt, plot = 'pr')
plot_model(tuned_dt, plot='feature')
plot_model(tuned_dt, plot = 'confusion_matrix')
evaluate_model(tuned_dt)
predict_model(tuned_dt);
final_dt = finalize_model(tuned_dt)
print(final_dt)
unseen_predictions = predict_model(final_dt, data=data_unseen)
unseen_predictions.head()
from pycaret.utils import check_metric
check_metric(unseen_predictions['Survived'], unseen_predictions['Label'], metric = 'Accuracy')
save_model(final_dt,'Final RF Model 11Nov2020')
saved_final_dt = load_model('Final RF Model 11Nov2020')
new_prediction = predict_model(saved_final_dt, data=data_unseen)
from pycaret.utils import check_metric
check_metric(new_prediction['Survived'], new_prediction['Label'], metric = 'Accuracy')

import pandas as pd
df=pd.read_csv('test.csv')
from pycaret.datasets import get_data
data = df
unseen_predictions = predict_model(final_dt, data=data)
unseen_predictions
S=unseen_predictions[["Label"]].to_numpy().flatten()
D=data.PassengerId.to_numpy().flatten()
D
#-------------------
# Submission!
#-------------------

output = pd.DataFrame({'PassengerId': D, 'Survived': S})
output.head()

output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
from google.colab import files

uploaded = files.download('submission.csv')

# %% [markdown]
# # **Lets drop cabin column to test accuracy**

# %%
df=pd.read_csv('train.csv')

df=df.drop(['Cabin'], axis=1)
from pycaret.datasets import get_data
dataset = df
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
df
import jinja2
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'Survived', session_id=123)
best_model = compare_models()
print(best_model)
models()
dt = create_model('gbc')
#trained model object is stored in the variable 'dt'. 
print(dt)
tuned_dt = tune_model(dt)
print(tuned_dt)
plot_model(tuned_dt, plot = 'auc')
plot_model(tuned_dt, plot = 'pr')
plot_model(tuned_dt, plot='feature')
plot_model(tuned_dt, plot = 'confusion_matrix')
evaluate_model(tuned_dt)
predict_model(tuned_dt);
final_dt = finalize_model(tuned_dt)
print(final_dt)
unseen_predictions = predict_model(final_dt, data=data_unseen)
unseen_predictions.head()
from pycaret.utils import check_metric
check_metric(unseen_predictions['Survived'], unseen_predictions['Label'], metric = 'Accuracy')
save_model(final_dt,'Final RF Model 11Nov2020')
saved_final_dt = load_model('Final RF Model 11Nov2020')
new_prediction = predict_model(saved_final_dt, data=data_unseen)
from pycaret.utils import check_metric
check_metric(new_prediction['Survived'], new_prediction['Label'], metric = 'Accuracy')

import pandas as pd
df=pd.read_csv('test.csv')
df=df.drop(['Cabin'], axis=1)

from pycaret.datasets import get_data
data = df
unseen_predictions = predict_model(final_dt, data=data)
unseen_predictions
S=unseen_predictions[["Label"]].to_numpy().flatten()
D=data.PassengerId.to_numpy().flatten()
D
#-------------------
# Submission!
#-------------------

output = pd.DataFrame({'PassengerId': D, 'Survived': S})
output.head()

output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
from google.colab import files

uploaded = files.download('submission.csv')

# %% [markdown]
# # **Lets drop embarked and cabin both**

# %%
df=pd.read_csv('train.csv')

df=df.drop(['Cabin', 'Embarked'], axis=1)
from pycaret.datasets import get_data
dataset = df
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
df
import jinja2
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'Survived', session_id=123)
best_model = compare_models()
print(best_model)
models()
dt = create_model('gbc')
#trained model object is stored in the variable 'dt'. 
print(dt)
tuned_dt = tune_model(dt)
print(tuned_dt)
plot_model(tuned_dt, plot = 'auc')
plot_model(tuned_dt, plot = 'pr')
plot_model(tuned_dt, plot='feature')
plot_model(tuned_dt, plot = 'confusion_matrix')
evaluate_model(tuned_dt)
predict_model(tuned_dt);
final_dt = finalize_model(tuned_dt)
print(final_dt)
unseen_predictions = predict_model(final_dt, data=data_unseen)
unseen_predictions.head()
from pycaret.utils import check_metric
check_metric(unseen_predictions['Survived'], unseen_predictions['Label'], metric = 'Accuracy')
save_model(final_dt,'Final RF Model 11Nov2020')
saved_final_dt = load_model('Final RF Model 11Nov2020')
new_prediction = predict_model(saved_final_dt, data=data_unseen)
from pycaret.utils import check_metric
check_metric(new_prediction['Survived'], new_prediction['Label'], metric = 'Accuracy')

import pandas as pd
df=pd.read_csv('test.csv')
df=df.drop(['Cabin', 'Embarked'], axis=1)

from pycaret.datasets import get_data
data = df
unseen_predictions = predict_model(final_dt, data=data)
unseen_predictions
S=unseen_predictions[["Label"]].to_numpy().flatten()
D=data.PassengerId.to_numpy().flatten()
D
#-------------------
# Submission!
#-------------------

output = pd.DataFrame({'PassengerId': D, 'Survived': S})
output.head()

output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
from google.colab import files

uploaded = files.download('submission.csv')

# %% [markdown]
# # **Dropping ticket and scaling age and Fare**

# %%
df=pd.read_csv('train.csv')

df=df.drop(['Ticket'], axis=1)
from pycaret.datasets import get_data
dataset = df
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
df
import jinja2
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'Survived', session_id=123)
best_model = compare_models()
print(best_model)
models()
dt = create_model('gbc')
#trained model object is stored in the variable 'dt'. 
print(dt)
tuned_dt = tune_model(dt)
print(tuned_dt)
plot_model(tuned_dt, plot = 'auc')
plot_model(tuned_dt, plot = 'pr')
plot_model(tuned_dt, plot='feature')
plot_model(tuned_dt, plot = 'confusion_matrix')
evaluate_model(tuned_dt)
predict_model(tuned_dt);
final_dt = finalize_model(tuned_dt)
print(final_dt)
unseen_predictions = predict_model(final_dt, data=data_unseen)
unseen_predictions.head()
from pycaret.utils import check_metric
check_metric(unseen_predictions['Survived'], unseen_predictions['Label'], metric = 'Accuracy')
save_model(final_dt,'Final RF Model 11Nov2020')
saved_final_dt = load_model('Final RF Model 11Nov2020')
new_prediction = predict_model(saved_final_dt, data=data_unseen)
from pycaret.utils import check_metric
check_metric(new_prediction['Survived'], new_prediction['Label'], metric = 'Accuracy')

import pandas as pd
df=pd.read_csv('test.csv')
df=df.drop(['Ticket'], axis=1)

from pycaret.datasets import get_data
data = df
unseen_predictions = predict_model(final_dt, data=data)
unseen_predictions
S=unseen_predictions[["Label"]].to_numpy().flatten()
D=data.PassengerId.to_numpy().flatten()
D
#-------------------
# Submission!
#-------------------

output = pd.DataFrame({'PassengerId': D, 'Survived': S})
output.head()

output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
from google.colab import files

uploaded = files.download('submission.csv')

# %% [markdown]
# # **Here we use first scaling of age column**

# %%
df=pd.read_csv('train.csv')

from sklearn.preprocessing import StandardScaler
# scale the train and test ages

scaler = StandardScaler()
df["Age"] = scaler.fit_transform(df["Age"] .values.reshape(-1,1))
df["Fare"] = scaler.fit_transform(df["Fare"] .values.reshape(-1,1))

# %%
from pycaret.utils import check_metric
import pandas as pd
from pycaret.datasets import get_data
from pycaret.utils import check_metric
from pycaret.datasets import get_data

dataset = df
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
df
import jinja2
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'Survived', session_id=123)
best_model = compare_models()
print(best_model)
models()
dt = create_model('gbc')
#trained model object is stored in the variable 'dt'. 
print(dt)
tuned_dt = tune_model(dt)
print(tuned_dt)
plot_model(tuned_dt, plot = 'auc')
plot_model(tuned_dt, plot = 'pr')
plot_model(tuned_dt, plot='feature')
plot_model(tuned_dt, plot = 'confusion_matrix')
evaluate_model(tuned_dt)
predict_model(tuned_dt);
final_dt = finalize_model(tuned_dt)
print(final_dt)
unseen_predictions = predict_model(final_dt, data=data_unseen)
unseen_predictions.head()

check_metric(unseen_predictions['Survived'], unseen_predictions['Label'], metric = 'Accuracy')
save_model(final_dt,'Final RF Model 11Nov2020')
saved_final_dt = load_model('Final RF Model 11Nov2020')
new_prediction = predict_model(saved_final_dt, data=data_unseen)

check_metric(new_prediction['Survived'], new_prediction['Label'], metric = 'Accuracy')

df=pd.read_csv('test.csv')

df["Age"] = scaler.fit_transform(df["Age"] .values.reshape(-1,1))
df["Fare"] = scaler.fit_transform(df["Fare"] .values.reshape(-1,1))

data = df
unseen_predictions = predict_model(final_dt, data=data)
unseen_predictions
S=unseen_predictions[["Label"]].to_numpy().flatten()
D=data.PassengerId.to_numpy().flatten()
D
#-------------------
# Submission!
#-------------------

output = pd.DataFrame({'PassengerId': D, 'Survived': S})
output.head()

output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
from google.colab import files

uploaded = files.download('submission.csv')

# %%
data

# %%
df=pd.read_csv('train.csv')

from sklearn.preprocessing import StandardScaler
# scale the train and test ages

scaler = StandardScaler()
df["Age"] = scaler.fit_transform(df["Age"] .values.reshape(-1,1))
df["Fare"] = scaler.fit_transform(df["Fare"] .values.reshape(-1,1))

df=df.drop(['Ticket'], axis=1)

# %%
from pycaret.utils import check_metric
import pandas as pd
from pycaret.datasets import get_data
from pycaret.utils import check_metric
from pycaret.datasets import get_data

dataset = df

data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
df
import jinja2
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'Survived', session_id=123)
best_model = compare_models()
print(best_model)
models()
dt = create_model('gbc')
#trained model object is stored in the variable 'dt'. 
print(dt)
tuned_dt = tune_model(dt)
print(tuned_dt)
plot_model(tuned_dt, plot = 'auc')
plot_model(tuned_dt, plot = 'pr')
plot_model(tuned_dt, plot='feature')
plot_model(tuned_dt, plot = 'confusion_matrix')
evaluate_model(tuned_dt)
predict_model(tuned_dt);
final_dt = finalize_model(tuned_dt)
print(final_dt)
unseen_predictions = predict_model(final_dt, data=data_unseen)
unseen_predictions.head()

check_metric(unseen_predictions['Survived'], unseen_predictions['Label'], metric = 'Accuracy')
save_model(final_dt,'Final RF Model 11Nov2020')
saved_final_dt = load_model('Final RF Model 11Nov2020')
new_prediction = predict_model(saved_final_dt, data=data_unseen)

check_metric(new_prediction['Survived'], new_prediction['Label'], metric = 'Accuracy')

df=pd.read_csv('test.csv')

df["Age"] = scaler.fit_transform(df["Age"] .values.reshape(-1,1))
df["Fare"] = scaler.fit_transform(df["Fare"] .values.reshape(-1,1))
df=df.drop(['Ticket'], axis=1)

data = df
unseen_predictions = predict_model(final_dt, data=data)
unseen_predictions
S=unseen_predictions[["Label"]].to_numpy().flatten()
D=data.PassengerId.to_numpy().flatten()
D
#-------------------
# Submission!
#-------------------

output = pd.DataFrame({'PassengerId': D, 'Survived': S})
output.head()

output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
from google.colab import files

uploaded = files.download('submission.csv')
